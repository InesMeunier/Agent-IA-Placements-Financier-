# %% [markdown]
# <a href="https://colab.research.google.com/github/InesMeunier/Agent-IA-Placements-Financier/blob/main/notebooks/biblioth%C3%A8que_de_donn%C3%A9es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #/!\Cloner le repo GitHub pour accéder aux dossiers

# %%
# !git clone https://github.com/InesMeunier/Agent-IA-Placements-Financier.git
# %cd Agent-IA-Placements-Financier
# !ls data
# Out:
# Cloning into 'Agent-IA-Placements-Financier'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 60 (delta 20), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 39.67 KiB | 1.59 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/Agent-IA-Placements-Financier
# assurance_vie.txt  lexique.txt	PER.txt

# %% [markdown]
# # Préparation environnement de travail

# %% [markdown]
# ##Installation et configuration

# %%
# !pip install llama-index -q
# !pip install llama-index-embeddings-huggingface
# !pip install jedi
# Out:
# ...
# WARNING: huggingface-hub 1.4.1 does not provide the extra 'inference'
# ...

# %%
import os
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
# from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from google.colab import userdata
# OpenAIAPIkey = userdata.get('OpenAIAPIkey')
HuggingFaceAPIkey = userdata.get('HuggingFaceAPIKey')

# %% [markdown]
# ##Clé API
# Me permet d'utiliser le modèle HuggingFace

# %%
# os.environ["OPENAI_API_KEY"] = OpenAIAPIkey
os.environ["HUGGINGFACE_API_KEY"] = HuggingFaceAPIkey

# %% [markdown]
# ##Chargement des documents

# %%
documents = SimpleDirectoryReader("data").load_data()
print(f"{len(documents)} documents chargés")
# Out:
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# 3 documents chargés

# %% [markdown]
# #Création de la BDD et des vecteurs

# %% [markdown]
# ##Transformation du texte en vecteur

# %%
# embed_model = OpenAIEmbedding()
# Sélection du modèle HuggingFace opensource pour transformer le texte en vecteurs numériques
embed_model = HuggingFaceEmbedding(
    model_name = "sentence-transformers/all-MiniLM-L6-v2"
)
# Pour chaque document, le découper en morceaux, transformer chaque morceau en vecteur et stocker les vecteurs dans un index (base optimisée pour la recherche)
index = VectorStoreIndex.from_documents(
    documents,
    embed_model = embed_model
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ##Sauvegarde de l'index

# %%
index.storage_context.persist(persist_dir="storage")

# %%
# !echo "storage/" >> .gitignore

# %%
# !ls -a
# Out:
# .   data  .gitignore	      notebooks  storage
# ..  .git  .ipynb_checkpoints  README.md

# %%
# %cd /content/Agent-IA-Placements-Financier
# Out:
# /content/Agent-IA-Placements-Financier

# %%
# !cat .gitignore
# Out:
# storage/

# %%
# !git config --global user.email "ines.meunier9@hotmail.fr"
# !git config --global user.name "InesMeunier"
# !git add .gitignore
# !git commit -m "Ajout fichier gitignore"
# !git push
# Out:
# [main 88c6a93] Ajout fichier gitignore
#  1 file changed, 1 insertion(+)
#  create mode 100644 notebooks/.gitignore
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %cd /content/Agent-IA-Placements-Financier
# !ls
# Out:
# /content/Agent-IA-Placements-Financier
# data  notebooks  README.md
