# %% [markdown]
# <a href="https://colab.research.google.com/github/InesMeunier/Agent-IA-Placements-Financier-/blob/main/biblioth%C3%A8que_de_donn%C3%A9es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello");
print("yo");
# Out:
# hello
# yo
